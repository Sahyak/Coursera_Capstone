# %% [markdown]
# # Python Capstone Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ### To Import The Covid 19 Dataset of INDIA

# %%
df=pd.read_csv('covid_19_india.csv')
# To display Dataset
df
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 7081  7082  07/10/20  8:00 AM            Telengana                       -
# 7082  7083  07/10/20  8:00 AM              Tripura                       -
# 7083  7084  07/10/20  8:00 AM          Uttarakhand                       -
# 7084  7085  07/10/20  8:00 AM        Uttar Pradesh                       -
# 7085  7086  07/10/20  8:00 AM          West Bengal                       -
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# ...

# %%
# State Wise number of 'Cured', 'Dead' and 'Confirmed' patients
Data=df.groupby(by='State/UnionTerritory').sum()[['Cured','Deaths','Confirmed']]
Data
# Out:
#                                              Cured   Deaths  Confirmed
# State/UnionTerritory
# Andaman and Nicobar Islands                 166515     2701     206048
# Andhra Pradesh                            25801839   292587   32689980
# Arunachal Pradesh                           257632      666     375408
# Assam                                      6719843    27255    8684022
# Bihar                                      8427148    51043   10083708
# Cases being reassigned to states                 0        0     345565
# Chandigarh                                  308365     5741     441054
# Chhattisgarh                               2286326    29781    3664704
# Dadar Nagar Haveli                              14        0        186
# Dadra and Nagar Haveli and Daman and Diu    149825      170     179185
# Daman & Diu                                      0        0          2
# Delhi                                     15548085   471261   18764283
# ...

# %%
# The Given Bar Graph shows you State Wise Patients in India. 
#The Yellow Bar is for Confirmed patients over time in each state. 
#Likewise Green and Read Bars are for Cured and Dead patients respectively.

df.groupby(by='State/UnionTerritory').sum().sort_values(by='Confirmed',ascending=False)[['Cured','Deaths','Confirmed']].plot(kind='bar',figsize=(20,8),color=['green','red','orange'])
plt.xlabel("States",fontsize=18)
plt.show()

# I have plotted the Bar graph in descending order as per confirmed patients. As you can see patients are more in Maharashtra State.

# %%
# Now I will only consider the data related to Maharashtra State
mahadata=df[df['State/UnionTerritory']=="Maharashtra"].drop(['ConfirmedIndianNational','ConfirmedForeignNational'],axis=1)
mahadata
# Out:
#        Sno      Date     Time State/UnionTerritory    Cured  Deaths  Confirmed
# 76      77  09/03/20  6:00 PM          Maharashtra        0       0          2
# 91      92  10/03/20  6:00 PM          Maharashtra        0       0          5
# 97      98  11/03/20  6:00 PM          Maharashtra        0       0          2
# 120    121  12/03/20  6:00 PM          Maharashtra        0       0         11
# 133    134  13/03/20  6:00 PM          Maharashtra        0       0         14
# ...    ...       ...      ...                  ...      ...     ...        ...
# 6930  6931  03/10/20  8:00 AM          Maharashtra  1117720   37480    1416513
# 6965  6966  04/10/20  8:00 AM          Maharashtra  1134555   37758    1430861
# 7000  7001  05/10/20  8:00 AM          Maharashtra  1149603   38084    1443409
# 7035  7036  06/10/20  8:00 AM          Maharashtra  1162585   38347    1453653
# 7070  7071  07/10/20  8:00 AM          Maharashtra  1179726   38717    1465911
#
# [213 rows x 7 columns]

# %%
# Here in this line graph we can see how the confirmed cases were increased in maharashtra over the time
# Given graph is expontial in nature
mahadata.plot(kind='line',x='Date',y='Confirmed',figsize=(20,8))
plt.xlabel('DATE')
plt.ylabel('CONFIRMED')
plt.show()

# %%
# Here in this line graph we can see how the confirmed cases were increased in Gujarat over the time
# Given graph is Linear in nature
gujdata=df[df['State/UnionTerritory']=="Gujarat"].drop(['ConfirmedIndianNational','ConfirmedForeignNational'],axis=1)
gujdata.plot(kind='line',x='Date',y='Confirmed',figsize=(20,8))
plt.xlabel('DATE')
plt.ylabel('CONFIRMED')
plt.show()

# %% [markdown]
# ### This means that the increase rate of patients was not same throughout the India

# %%
# The Pie Chart shows number of deaths in india per state
Data.plot(kind='pie',y='Deaths',legend=False,figsize=(45,8))
plt.title("DEATHS")
plt.show()
